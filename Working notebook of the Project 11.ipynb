# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
import os

# %%
## feature extraction on crazing images using cv2 find contours

# %%
# import image grayscale format
img = cv.imread(r'C:\Users\nagaya\Desktop\ACADEMIC\1.2 Semester\Techlabs\01_Project Metal defect detection\archive\NEU Metal Surface Defects Data\train\Crazing\Cr_99.bmp',cv.IMREAD_GRAYSCALE)
# adaptive Threshold for better detection of defect regions used cv.ADAPTIVE_THRESH_MEAN_C
binary = cv.adaptiveThreshold(img3,255,cv.ADAPTIVE_THRESH_MEAN_C,cv.THRESH_BINARY_INV,41,30)
plt.imshow(binary, cmap="gray")
plt.show()

# %%
contours, hierachy = cv.findContours(binary, cv.RETR_TREE,cv.CHAIN_APPROX_SIMPLE)
image = cv.drawContours(img3,contours,-1,(0,255,3),1)
plt.imshow(image,cmap='gray')
plt.show()

# %%
img1 = cv.imread(r'C:\Users\nagaya\Desktop\ACADEMIC\1.2 Semester\Techlabs\01_Project Metal defect detection\archive\NEU Metal Surface Defects Data\train\Crazing\Cr_99.bmp',cv.IMREAD_GRAYSCALE)
# adaptive Threshold for better detection of defect regions used cv.ADAPTIVE_THRESH_MEAN_C
binary = cv.adaptiveThreshold(img1,255,cv.ADAPTIVE_THRESH_GAUSSIAN_C,cv.THRESH_BINARY_INV,71,30)
plt.imshow(binary, cmap="gray")
plt.show()

# %%
contours, hierachy = cv.findContours(binary, cv.RETR_LIST,cv.CHAIN_APPROX_SIMPLE)
image = cv.drawContours(img1,contours,-1,(0,255,3),1)
plt.imshow(image,cmap='gray')
plt.show()

# %%
# this code isn't good as it not able to extract the features of inclusions properly for all set of images

img3 = cv.imread(r"C:\Users\nagaya\Desktop\ACADEMIC\1.2 Semester\Techlabs\01_Project Metal defect detection\archive\NEU Metal Surface Defects Data\train\Inclusion\In_293.bmp",0)
binary = cv.adaptiveThreshold(img3,255,cv.ADAPTIVE_THRESH_MEAN_C,cv.THRESH_BINARY_INV,7,-7)
plt.imshow(binary, cmap="gray")
plt.show()

# %%
contours, hierachy = cv.findContours(binary, cv.RETR_TREE,cv.CHAIN_APPROX_SIMPLE)
image = cv.drawContours(img3,contours,-1,(0,255,3),1)
plt.imshow(image,cmap='gray')
plt.show()
